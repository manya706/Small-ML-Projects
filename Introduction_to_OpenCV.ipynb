# %% [markdown]
# <a href="https://colab.research.google.com/github/manya706/Small-ML-Projects/blob/main/Introduction_to_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2
from google.colab.patches import cv2_imshow
# Reading the image using imread() function
image = cv2.imread('/content/demo image.jfif',cv2.IMREAD_COLOR)
img = cv2.imread('/content/demo image.jfif',cv2.IMREAD_COLOR)
cv2_imshow(image)
# Extracting the height and width of an image
h, w = image.shape[:2]
# Displaying the height and width
print("Height = {},  Width = {}".format(h, w))
# Out:
# <PIL.Image.Image image mode=RGB size=289x174>
# Height = 174,  Width = 289

# %%
B, G, R = cv2.split(image)
cv2_imshow(image)
cv2.waitKey(0)

cv2_imshow( B)
cv2.waitKey(0)

cv2_imshow( G)
cv2.waitKey(0)

cv2_imshow( R)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=289x174>
# <PIL.Image.Image image mode=L size=289x174>
# <PIL.Image.Image image mode=L size=289x174>
# <PIL.Image.Image image mode=L size=289x174>
# -1

# %%
from matplotlib import pyplot as plt
# convert image to gray scale image
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# detect corners with the goodFeaturesToTrack function.
corners = cv2.goodFeaturesToTrack(gray, 27, 0.01, 10)
corners = np.int0(corners)

# we iterate through each corner,
# making a circle at each point that we think is a corner.
for i in corners:
    x, y = i.ravel()
    cv2.circle(image, (x, y), 3, 255, -1)
    print(x,y)
plt.imshow(image), plt.show()
# Out:
# 41 39
# 237 17
# 102 111
# 66 47
# 54 48
# 23 114
# 66 107
# 151 167
# 82 57
# 34 129
# 93 55
# 107 78
# 141 75
# 127 87
# 162 105
# 143 138
# 29 23
# 232 151
# 89 114
# 115 64
# 165 124
# 192 130
# 162 164
# 165 91
# 188 44
# 195 56
# 188 74
# (<matplotlib.image.AxesImage at 0x7e1bfa5619c0>, None)

# %%
for i, row in enumerate(image):

  # get the pixel values by iterating
    for j, pixel in enumerate(image):
        if(i == j or i+j == image.shape[0]):

                # update the pixel value to black/white
            image[i][j] = [0, 0, 0]

# display image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=289x174>

# %%
(cX,cY) = (w/2,h/2)
t1 = image[0,0]
tr = image[0,w-1]
br = image[h-1,w-1]
bl = image[h-1,0]
print(t1,tr,bl,br)
# Out:
# [232 232 232] [27 58 57] [ 0 38 17] [16 45 20]

# %%
centre = img[h//2,w//2]
img[h//2,w//2] = (255,255,255)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=289x174>

# %%
image[0,0] = (0,255,255)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=289x174>

# %%
import numpy as np
kernel = np.ones((5, 5), np.uint8)

# The first parameter is the original image,
# kernel is the matrix with which image is
# convolved and third parameter is the number
# of iterations, which will determine how much
# you want to erode/dilate a given image.
img_erosion = cv2.erode(image, kernel, iterations=1)
img_dilation = cv2.dilate(image, kernel, iterations=1)

cv2_imshow(image)
cv2_imshow( img_erosion)
cv2_imshow( img_dilation)

cv2.waitKey(0)
